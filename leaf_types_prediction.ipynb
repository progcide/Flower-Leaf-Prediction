# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()

# %%
dir(iris_data)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris_data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris_data.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
iris_data.data.shape
# Out:
# (150, 4)

# %%
iris_data.feature_names[1]
# Out:
# 'sepal width (cm)'
